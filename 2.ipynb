# %% [markdown]
# <img src="https://logos-download.com/wp-content/uploads/2016/10/Python_logo_wordmark.png" width=256 height=64 align="left">
#
#
# # 10分钟快速入门
#
# ## Python的版本
#
# * Python的版本号表示为Python major.minor.bugfix。其中major版本基本不变，minor版本具有新的和增强功能，bugfix版本是错误修正和安全补丁。
#
# * Python 2.x.x已于2020年1月1日正式终止 (2.7.16)。目前官方仅支持3.5.x及后续版本，其中最新版为2019年12月18日发布的3.8.1。
#
# * Python 3.x.x并不向下兼容Python 2.x.x。一些使用Python 2.x.x语法和库的程序，不经过修改无法在Python 3.x.x上运行。
#
# ## Python的安装
#
# ### 方法一：Anaconda
#
# [Anaconda](https://www.anaconda.com/)是一个免费开源、用于科学计算的Python发行版。它提供了软件包管理工具Conda和用户图形界面Anaconda Navigator，大大简化了Python环境配置和软件包的管理和部署。用户可以通过Anaconda Navigator启动应用（比如JupyterLab），配置Python运行环境，安装和升级软件包等。可以利用Conda命令更新到最新版本：
# ~~~
# conda update conda
# ~~~
#
# 建议初学者用此方法安装和使用Python。典型安装将占用3GB的硬盘空间。如需减少空间占用，可选择安装[Miniconda](https://docs.conda.io/en/latest/miniconda.html)（约400MB），再使用Conda命令安装需要的软件包，如
# ~~~
# conda install numpy
# conda install anaconda-navigator
# ~~~
# 必要的软件包包括：
# * [NumPy](https://www.numpy.org)：高维数组与矩阵运算库
# * [SciPy](https://www.scipy.org)：算法库和数学工具包
# * [Matplotlib](https://matplotlib.org/)：图形绘制库
#
# 其他建议安装的软件包包括：
# * [JupyterLab](https://jupyter.org/)或Jupyter Notebook：基于Web的交互式计算平台
# * Anaconda Navigator：Anaconda的图形用户界面
#
# ### 方法二：pip
#
# 首先，Python可从[Python Software Foundation的网站](https://www.python.org/)下载。Python支持Windows, Linux/UNIX, macOS以及其他一些操作系统。只需根据使用的操作系统下载相应的安装包安装即可。
#
# 对于Windows安装包（msi文件），安装程序默认将文件安装到带有版本号的文件夹（如`C:\Python38\`），因此不同版本之间不会发生冲突。但安装程序不会更改系统`PATH`环境变量。如要运行某个版本的Python解释器，可在命令行窗口入其全路径名（如`C:\Python38\python`），或者为方便起见，将Python的路径加入`PATH`环境变量。可通过在`powershell`中运行以下命令实现：
# ~~~
# [Environment]::SetEnvironmentVariable("Path", "$env:Path;C:\Python38\;C:\Python38\Scripts\", "User")
# ~~~
#
# macOS和多数Linux发行版自带Python环境。但macOS（包括最新版macOS Catalina）附带Python 2.7是为了与旧版软件兼容，因此不建议使用，应当下载使用Python 3。
#
# 设置好环境变量后，在操作系统的命令行界面（command-line interface, CLI）运行`Python`，即可启动Python的命令行界面，表明Python已成功安装。如要退出可输入`exit()`。多条命令构成的Python脚本可用任意纯文本编辑器生成和修改。脚本文件的扩展名为`.py`。
#
# Python提供了[pip](https://pip.pypa.io/)和setuptools，用来安装和更新Python包。例如将pip更新为最新版本，可运行
#
# Linux / OSX上:
# ~~~
# pip install -U pip
# ~~~
# Windiows上:
# ~~~
# python -m pip install -U pip
# ~~~
#
# 如要安装NumPy包，可运行
# ~~~
# pip install numpy
# ~~~

# %% [markdown]
# ## 获取Python集成开发环境
#
# 和其他编程语言一样，Python程序可以用任何纯文本编辑程序（如TextEdit, VIM, notepad等等）编写并在命令行或终端窗口运行和调试。但集成开发环境（Integrated Development Environment, IDE）可使这些工作变得简单，同时具有许多普通编辑器做不到的额外功能，如错误检查、代码自动完成等。
#
# 这里列举几种广为采用的IDE:
#
# * JupyterLab/Jupyter Notebook。基于Web的开源、免费科学计算平台。
# * Spyder Phython。Python编写的开源、免费IDE。适用于科学计算。
# * PyCharm。JetBrains公司开发的Python IDE。有免费社区版和功能更多的付费专业版。
# * Pydev with Eclipse。Eclipse是著名的开源IDE，Pydev是其Python插件。
# * VIM。经典的文本剪辑器，可配置成Python集成开发环境。不支持鼠标。

# %% [markdown]
# ## JupyterLab/Jupyter Notebook
#
# [JupyterLab](https://jupyter.org/)是一种基于web的交互式计算平台。其生成的ipynb文件是一种可包含Python代码、代码执行结果、文字、数学公式、图形、图像的JSON文件。它也可以视为是Python的交互式解释器和记录工具。
#
# 建议使用此方式完成实验报告。

# %% [markdown]
# ## 安装Python太麻烦了，怎么办？
#
# 如果操作系统是Windows，可以下载使用[Portable版本](https://www.portabledevapps.net/)。Portable版本已预先配置好，所有文件都在一个文件夹内，可以拷贝在移动介质上并在任意Windows电脑上运行。
#
# 或者可以在线使用基于云的Jupyter Notebook服务，不需要在电脑上安装任何软件和进行任何配置，通过web浏览器即可免费使用：
#
# * [Microsoft Azure Notebooks](https://notebooks.azure.com/)，用Microsoft或Outlook账户登录即可使用。
#
# * [Google Colaboratory](https://colab.research.google.com/)，有Google账户即可登录使用。
#
# 但要注意在线服务可能有一定的局限。
#
#
# ## Hello World!
#
# 在Python CLI输入

# %%
print("Hello world!") # 输出 Hello World!
# Out:
# Hello world!

# %% [markdown]
# 语句会立即被执行并显示输出结果。其中`print()`是函数，`"Hello World!"`是函数的参数。Python用`#`号作为注释符号。用文本编辑器将该命令保存为Python脚本文件（如script.py），在命令行输入以下命名即可执行该脚本：
# ```
# python script.py
# ```
#
# ## 变量类型
#
# Python中的变量不需要进行类型声明，变量在赋值时会自动确定类型（整数、长整数、浮点数、复数、字符串等）并分配内存。如：

# %%
a=4             #整数
b=3.1           #浮点数
c=a+b*(0+1.0j)  #复数
d=0xe           #十六进制整数
a,b,c,d
# Out:
# (4, 3.1, (4+3.1j), 14)

# %% [markdown]
# 支持同时给多个变量同时赋值：

# %%
e=f=g=a
e,f,g
# Out:
# (4, 4, 4)

# %% [markdown]
# Python是面向对象的编程语言，变量实际上也是各个模块、类、函数中不同名字的对象。Python具有垃圾回收功能，但也可以用`del`语句删除一个或多个对象，如：

# %%
del e,f

# %% [markdown]
# 可以定义字符串并对其进行引用：

# %%
e="Hello world!"
e[1:9]
# Out:
# 'ello wor'

# %% [markdown]
# ## 基本运算符
#
# 除了`+`、`-`、`*`、`/`等基本运算外，还有

# %%
e = a // b    # 除后向下取整
f = a % b     # 除后取余
e,f
# Out:
# (1.0, 0.8999999999999999)

# %% [markdown]
# ## 比较运算符
#
# 等于`==`、不等于`！=`、大于`>`、小于`<`、大于等于`>=`、小于等于`<=`等。

# %% [markdown]
# ## 逻辑运算符
# 与`and`、或`or`、非`not`。

# %% [markdown]
# ## 条件语句
#
# if条件语句的示例如下：

# %%
num = -3
if num > 0:
    print("This number is positive.")
elif num==0:
    print("This number is zero.")
else:
    print("这个数字是负的。")
# Out:
# 这个数字是负的。

# %% [markdown]
# ## 循环语句
#
# Python for和while循环语句的实例如下：

# %%
for num in range(1,5,2):
    print(num)
# Out:
# 1
# 3

# %%
num = 1;
while num < 5:
    print(num)
    num += 2
# Out:
# 1
# 3

# %% [markdown]
# ## 函数
#
# 定义一个完成特定功能的函数，实例如下：

# %%
def mysum(a,b):
    return a+b

c=mysum(1,2)
c
# Out:
# 3

# %% [markdown]
# ## 模块
#
# 模块是保存了Python代码的文件，其中可定义某些函数、类以及变量。模块本身也是对象，可以用任意的名字来绑定和使用。如

# %%
import math as m
m.fabs(-1)
# Out:
# 1.0

# %% [markdown]
# ## NumPy + SciPy + Matplotlib
#
# 通过这三个第三方扩展库， Python可用来实现与MATLAB相似的功能。

# %% [markdown]
# ### NumPy
#
# NumPy是Python的一个扩展库，使Python可以进行大规模数组和矩阵运算，并提供大量支持矩阵运算的函数库。与MATLAB相比，两者都是利用BLAS和LAPACK
# 来进行高效线性代数运算，NumPy提供了许多与MATLAB相似的功能和操作方式，但NumPy是基于Python这个更为现代和开放的编程语言，因此使用范围更为广阔。

# %%
import numpy as np
x = np.array([2, 3, 5, 7])    # 新建行向量x
y = 2*x+1                     # 定于行向量y
y
# Out:
# array([ 5,  7, 11, 15])

# %%
y[2] = y[2] - 5
y
# Out:
# array([ 5,  7,  6, 15])

# %% [markdown]
# ### SciPy
#
# SciPy是在NumPy矩阵运算基础上的算法库和数学工具包，其包含的模块有快速傅里叶变换、数值积分、插值、线性代数、图像处理、最优化、信号处理、以及其他科学与工程中常用的计算等。

# %% [markdown]
# ### Matplotlib
#
# Matplotlib是NumPy基础上的画图软件包，其中pyplot模块提供了与MATLAB画图相似的界面。

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
import matplotlib.pyplot as plt
import numpy as np
a = np.linspace(0,4*np.pi,300)
b = np.sin(a)
c = np.cos(a)
fig, ax = plt.subplots(figsize=(8, 4.5))
scaling=[0,4*np.pi,-1.1,1.1]
ax.axis(scaling)
ax.plot(a,b,label='sin(x)')
ax.plot(a,c,label='cos(x)')
ax.legend()
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Sine and Cosine Functions')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
k1=-4
k2=7
n=0
k=np.arange(k1,k2)
x=np.zeros(k2-k1)
x1=np.zeros(k2-k1)
x[n-k1]=1
x1[n-k1:k2-k1]=1
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(12, 4.5))
scaling=[k1,k2-1,-.1,1.1]
ax1.stem(k,x)
ax2.stem(k,x1)
ax1.axis(scaling)
ax2.axis(scaling)
ax1.set_xlabel('n')
ax2.set_xlabel('n')
ax1.set_title('Discrete Impulse Function')
ax2.set_title('Discrete Step Function')
plt.show()
